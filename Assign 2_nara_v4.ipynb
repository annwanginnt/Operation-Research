# %%
from gurobipy import GRB
import gurobipy as gb
from gurobipy import *
import numpy as np

# %% [markdown]
# # Question 1

# %% [markdown]
# # a

# %%
isVariablePricing = True

# %%
# Linear price response functions (intercept, slope)
response = [[35234.5457855123, 45.8964497063843], [37790.2408321369, 8.22779417263456]]

# Create a new optimization model to maximize revenue
model = gb.Model("Variable Pricing Model")

# %%
a1, b1 = response[0]
a2, b2 = response[1]

# %%
p1 = model.addVar(lb=0, vtype=GRB.CONTINUOUS, name="p1")  # Price for Basic version
p2 = model.addVar(lb=0, vtype=GRB.CONTINUOUS, name="p2")  # Price for Advanced version

# %%
model.setObjective(p1*(a1 - b1*p1) + p2*(a2 - b2*p2), sense=GRB.MAXIMIZE)

# %%
model.addConstr(p1 <= p2, "price_ordering_constraint")

# Demand non-negativity constraints
model.addConstr(a1 - b1*p1 >= 0, "demand_nonnegativity_p1")
model.addConstr(a2 - b2*p2 >= 0, "demand_nonnegativity_p2")
# Out:
# <gurobi.Constr *Awaiting Model Update*>

# %%
model.optimize()
# Out:
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11.0 (22621.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 3 rows, 2 columns and 4 nonzeros
# Model fingerprint: 0xf11202ab
# Model has 2 quadratic objective terms
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+01]
#   Objective range  [4e+04, 4e+04]
#   QObjective range [2e+01, 9e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+04, 4e+04]
# Presolve removed 2 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 1 rows, 2 columns, 2 nonzeros
# Presolved model has 2 quadratic objective terms
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 0.000e+00
#  Factor NZ  : 1.000e+00
#  Factor Ops : 1.000e+00 (less than 1 second per iteration)
#  Threads    : 1
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0  -2.57192088e+08  1.88361074e+09  8.82e+02 2.92e+02  1.31e+06     0s
#    1   4.70835123e+07  9.24858776e+08  0.00e+00 2.92e-04  1.71e+05     0s
#    2   4.85280827e+07  7.34061921e+07  0.00e+00 5.29e-06  4.86e+03     0s
#    3   5.01514252e+07  5.11105696e+07  0.00e+00 5.29e-12  1.87e+02     0s
#    4   5.01549833e+07  5.01559414e+07  0.00e+00 1.42e-14  1.87e-01     0s
#    5   5.01549833e+07  5.01549843e+07  0.00e+00 2.84e-14  1.87e-04     0s
#    6   5.01549833e+07  5.01549833e+07  0.00e+00 2.84e-14  1.87e-07     0s
#    7   5.01549833e+07  5.01549833e+07  0.00e+00 5.68e-14  1.88e-10     0s
#
# Barrier solved model in 7 iterations and 0.01 seconds (0.00 work units)
# Optimal objective 5.01549833e+07

# %%
print("Optimal price for the Basic version (p1):", p1.X)
print("Optimal price for the Advanced version (p2):", p2.X)
# Out:
# Optimal price for the Basic version (p1): 383.84827160836835
# Optimal price for the Advanced version (p2): 2296.49891813207

# %% [markdown]
# ## b

# %%
p1 = 0
p2 = 0
step_size = 0.001
stopping_criterion = 1e-6

# %%
proj_model = gb.Model("Projected_Gradient_Descent")

# %%
p1_var = proj_model.addVar(lb=0, vtype=GRB.CONTINUOUS, name="p1")
p2_var = proj_model.addVar(lb=0, vtype=GRB.CONTINUOUS, name="p2")

# %%
objective_expr = p1*(a1 - b1*p1_var) + p2*(a2 - b2*p1_var)
proj_model.setObjective(objective_expr, GRB.MAXIMIZE)

# %%
constraint1 = proj_model.addConstr(p1_var <= p2_var, name="price_ordering")
constraint2 = proj_model.addConstr(a1 - b1 * p1_var >= 0, name="demand_non_negativity1")
constraint3 = proj_model.addConstr(a2 - b2 * p2_var >= 0, name="demand_non_negativity2")

# %%
proj_model.update()
proj_model.Params.OutputFlag = 0  # Suppress Gurobi output

# %%
while True:
    # Solve current model
    proj_model.optimize()

    # Extract current prices
    p1_curr = p1_var.X
    p2_curr = p2_var.X

    # Compute gradients
    gradient_p1 = a1 - 2 * b1 * p1_curr
    gradient_p2 = a2 - 2 * b2 * p2_curr

    # Update prices
    p1_next = max(p1_curr + step_size * gradient_p1, 0)
    p2_next = max(p2_curr + step_size * gradient_p2, 0)

    # Update variables
    p1_var.lb = p1_next
    p2_var.lb = p2_next

    # Check stopping criterion
    if max(abs(p1_next - p1_curr), abs(p2_next - p2_curr)) < stopping_criterion:
        break

    # Update current prices
    p1 = p1_next
    p2 = p2_next

# %%
print("Optimal prices:")
print("p1:", p1)
print("p2:", p2)
# Out:
# Optimal prices:
# p1: 383.84827160837096
# p2: 2296.4988578305542

# %% [markdown]
# # c

# %%
a = [[35234.5457855123, 37790.24083, 35675.33322],
    [37041.38038, 36846.14039, 35827.02375],
    [39414.26632, 35991.95146, 39313.31703]]

b = [[45.8964497063843, 8.22779417263456, 7.5844364095833],
    [9.03316640448659, 4.42786920644331, 2.62906001535909],
    [2.42148391836987, 4.00051240063997, 2.29662237308723]]

capacity = [[80020, 89666, 80638],
            [86740, 84050, 86565],
            [87051, 85156, 87588]]

# %%
model_c = gb.Model("LaptopPricing")

# %%
prices = {}
for i in range(3):
    for j in range(3):
        prices[i,j] = model_c.addVar(lb=0, vtype=GRB.CONTINUOUS, name=f"Price_{i}_{j}")

# %%
revenue = gb.quicksum(prices[i,j] * (a[i][j] - b[i][j] * prices[i,j]) for i in range(3) for j in range(3))
model_c.setObjective(revenue, GRB.MAXIMIZE)

# %%
for i in range(3):
    for j in range(3):
        model_c.addConstr(a[i][j] - b[i][j] * prices[i,j] >= 0)

# %%
for i in range(3):
    for j in range(3):
        model_c.addConstr(a[i][j] - b[i][j] * prices[i,j]<= capacity[i][j])

# %%
for i in range(3):
    model_c.addConstr(prices[i, 0] <= prices[i, 1])
    model_c.addConstr(prices[i, 1] <= prices[i, 2])

# %%
model_c.optimize()
# Out:
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11.0 (22621.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 24 rows, 9 columns and 30 nonzeros
# Model fingerprint: 0x8744217b
# Model has 9 quadratic objective terms
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+01]
#   Objective range  [4e+04, 4e+04]
#   QObjective range [5e+00, 9e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+04, 5e+04]
# Presolve removed 18 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 6 rows, 9 columns, 12 nonzeros
# Presolved model has 9 quadratic objective terms
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 3.000e+00
#  Factor NZ  : 9.000e+00
#  Factor Ops : 1.500e+01 (less than 1 second per iteration)
#  Threads    : 1
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0  -2.46664867e+08  7.94411343e+09  8.88e+02 5.65e+02  1.40e+06     0s
#    1   6.54979287e+08  2.94549402e+09  0.00e+00 5.65e-04  1.86e+05     0s
#    2   7.00528563e+08  8.21522546e+08  0.00e+00 1.27e-05  9.85e+03     0s
#    3   7.16772545e+08  7.23350467e+08  0.00e+00 9.63e-08  5.35e+02     0s
#    4   7.18322189e+08  7.18505328e+08  0.00e+00 2.27e-13  1.49e+01     0s
#    5   7.18378050e+08  7.18401860e+08  0.00e+00 0.00e+00  1.94e+00     0s
#    6   7.18382031e+08  7.18383993e+08  0.00e+00 2.27e-13  1.60e-01     0s
#    7   7.18382098e+08  7.18382111e+08  0.00e+00 5.68e-14  1.06e-03     0s
#    8   7.18382098e+08  7.18382098e+08  0.00e+00 1.14e-13  1.06e-06     0s
#    9   7.18382098e+08  7.18382098e+08  0.00e+00 1.14e-13  1.06e-09     0s
#
# Barrier solved model in 9 iterations and 0.02 seconds (0.00 work units)
# Optimal objective 7.18382098e+08

# %%
if model_c.status == GRB.OPTIMAL:
    print("Optimal Revenue: $", round(model_c.objVal, 2))
else:
    print("Optimization could not be completed.")
# Out:
# Optimal Revenue: $ 718382097.68

# %%
print("Optimal Prices:")
for i in range(3):
    for j in range(3):
        print(f"Product Line {i+1}, Version {j+1}: ${prices[i, j].X}")
# Out:
# Optimal Prices:
# Product Line 1, Version 1: $383.8482716083712
# Product Line 1, Version 2: $2296.4989179882505
# Product Line 1, Version 3: $2351.8776672154513
# Product Line 2, Version 1: $2050.2987945402124
# Product Line 2, Version 2: $4160.707856544469
# Product Line 2, Version 3: $6813.656504738742
# Product Line 3, Version 1: $5870.932809225458
# Product Line 3, Version 2: $5870.93280922546
# Product Line 3, Version 3: $8558.94236046154

# %% [markdown]
# # d

# %%
model_d = gb.Model("Pricingconstraints")

# %%
prices_d = {}
for i in range(3):
    for j in range(3):
        prices_d[i,j] = model_d.addVar(lb=0, vtype=GRB.CONTINUOUS, name=f"Price_{i}_{j}")

# %%
revenue = gb.quicksum(prices_d[i,j] * (a[i][j] - b[i][j] * prices_d[i,j]) for i in range(3) for j in range(3))
model_d.setObjective(revenue, GRB.MAXIMIZE)

# %%
for i in range(3):
    for j in range(3):
        model_d.addConstr(a[i][j] - b[i][j] * prices_d[i,j] >= 0)

# %%
for i in range(3):
    for j in range(3):
        model_d.addConstr(a[i][j] - b[i][j] * prices_d[i,j]<= capacity[i][j])

# %%
for i in range(3):
    model_d.addConstr(prices_d[i, 0] <= prices_d[i, 1])
    model_d.addConstr(prices_d[i, 1] <= prices_d[i, 2])

# %%
for j in range(3):
    model_d.addConstr(prices_d[0, j] <= prices_d[1, j])
    model_d.addConstr(prices_d[1, j] <= prices_d[2, j])

# %%
model_d.optimize()
# Out:
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11.0 (22621.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 30 rows, 9 columns and 42 nonzeros
# Model fingerprint: 0x5b313137
# Model has 9 quadratic objective terms
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+01]
#   Objective range  [4e+04, 4e+04]
#   QObjective range [5e+00, 9e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+04, 5e+04]
# Presolve removed 18 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 12 rows, 9 columns, 24 nonzeros
# Presolved model has 9 quadratic objective terms
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 2.200e+01
#  Factor NZ  : 7.800e+01
#  Factor Ops : 6.500e+02 (less than 1 second per iteration)
#  Threads    : 1
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0  -2.32251734e+08  7.86916556e+09  9.87e+02 7.02e+02  1.35e+06     0s
#    1   6.46602194e+08  3.40523493e+09  0.00e+00 7.02e-04  1.80e+05     0s
#    2   6.96106134e+08  8.63659542e+08  0.00e+00 2.09e-05  1.09e+04     0s
#    3   7.17353672e+08  7.23295779e+08  0.00e+00 1.37e-07  3.87e+02     0s
#    4   7.18341203e+08  7.18488841e+08  0.00e+00 3.95e-12  9.61e+00     0s
#    5   7.18379583e+08  7.18396773e+08  0.00e+00 1.14e-13  1.12e+00     0s
#    6   7.18382070e+08  7.18383285e+08  0.00e+00 1.14e-13  7.91e-02     0s
#    7   7.18382098e+08  7.18382101e+08  0.00e+00 5.68e-14  2.40e-04     0s
#    8   7.18382098e+08  7.18382098e+08  0.00e+00 1.14e-13  2.40e-07     0s
#    9   7.18382098e+08  7.18382098e+08  0.00e+00 1.14e-13  2.40e-10     0s
#
# Barrier solved model in 9 iterations and 0.01 seconds (0.00 work units)
# Optimal objective 7.18382098e+08

# %%
if model_d.status == GRB.OPTIMAL:
    print("Optimal Revenue: $", round(model_d.objVal, 2))
else:
    print("Optimization could not be completed.")
# Out:
# Optimal Revenue: $ 718382097.68

# %%
print("Optimal Prices:")
for i in range(3):
    for j in range(3):
        print(f"Product Line {i+1}, Version {j+1}: ${prices_d[i, j].X}")
# Out:
# Optimal Prices:
# Product Line 1, Version 1: $383.84827160837125
# Product Line 1, Version 2: $2296.4989179982404
# Product Line 1, Version 3: $2351.8776672046133
# Product Line 2, Version 1: $2050.2987945402124
# Product Line 2, Version 2: $4160.707856544468
# Product Line 2, Version 3: $6813.656504738741
# Product Line 3, Version 1: $5870.932809225459
# Product Line 3, Version 2: $5870.932809225459
# Product Line 3, Version 3: $8558.94236046154

# %% [markdown]
# # Question 2

# %%
import pandas as pd

# %%
m = gb.Model("TrainingCampSelection")

# %%
invited = m.addVars(150, vtype=GRB.BINARY, name="Selected Players")

# %%
skills =pd.read_csv(r'https://raw.githubusercontent.com/Ninja-Apprentice/Modelling-and-Application/main/BasketballPlayers.csv')
skills
# Out:
#      Number Position  Ball Handling  Shooting  Rebounding  Defense
# 0         1      G/F              1         2           3        2  \
# 1         2      G/F              1         1           1        2
# 2         3      G/F              3         1           1        2
# 3         4      G/F              2         3           2        2
# 4         5      F/C              1         2           3        3
# ..      ...      ...            ...       ...         ...      ...
# 145     146      F/C              2         2           3        1
# 146     147      G/F              2         3           2        3
# 147     148      G/F              3         1           2        3
# 148     149      F/C              1         2           3        1
# 149     150      F/C              1         3           2        1
#
#      Athletic Ability  Toughness  Mental Acuity
# 0                   1          2              1
# 1                   3          2              3
# 2                   3          2              1
# 3                   2          1              1
# 4                   3          3              2
# ..                ...        ...            ...
# 145                 1          3              3
# 146                 2          2              2
# 147                 2          3              3
# 148                 1          2              2
# 149                 3          2              3
#
# [150 rows x 9 columns]

# %%
skills_rating = skills.iloc[:, 2:].values
skills_rating
# Out:
# array([[1, 2, 3, ..., 1, 2, 1],
#        [1, 1, 1, ..., 3, 2, 3],
#        [3, 1, 1, ..., 3, 2, 1],
#        ...,
#        [3, 1, 2, ..., 2, 3, 3],
#        [1, 2, 3, ..., 1, 2, 2],
#        [1, 3, 2, ..., 3, 2, 3]], dtype=int64)

# %%
players_positions = skills.iloc[:, 1].values
players_positions
# Out:
# array(['G/F', 'G/F', 'G/F', 'G/F', 'F/C', 'G', 'F/C', 'F/C', 'G', 'G/F',
#        'F', 'F/C', 'G/F', 'F', 'G', 'G', 'G', 'F/C', 'F/C', 'G/F', 'F',
#        'F/C', 'G', 'F', 'G', 'G', 'G', 'F', 'G', 'G/F', 'G', 'F', 'F',
#        'F/C', 'F', 'F/C', 'G/F', 'F/C', 'F', 'G', 'F', 'F', 'G', 'F',
#        'F/C', 'F', 'G/F', 'F/C', 'G', 'G/F', 'F', 'G/F', 'F', 'F', 'F',
#        'F/C', 'F', 'F', 'F/C', 'G', 'F/C', 'F', 'F', 'G', 'F', 'F', 'G',
#        'F', 'G', 'F', 'F', 'F', 'G', 'F/C', 'G/F', 'F', 'F', 'G', 'F',
#        'G', 'G/F', 'G/F', 'F/C', 'F', 'G/F', 'G/F', 'G', 'G/F', 'G/F',
#        'F', 'G/F', 'G/F', 'F', 'G', 'G/F', 'G/F', 'F', 'F/C', 'G/F',
#        'G/F', 'F/C', 'G', 'F', 'G', 'F/C', 'F', 'G', 'F/C', 'G', 'G', 'F',
#        'G', 'F/C', 'F/C', 'G', 'F/C', 'F/C', 'G/F', 'G', 'G', 'F', 'F',
#        'G', 'F', 'F/C', 'F/C', 'F', 'G/F', 'G', 'F', 'F', 'G/F', 'F',
#        'F/C', 'G', 'F/C', 'F', 'G', 'F/C', 'F', 'G', 'F', 'G', 'F', 'F',
#        'F/C', 'G/F', 'G/F', 'F/C', 'F/C'], dtype=object)

# %%
skills_rating[2]
# Out:
# array([3, 1, 1, 2, 3, 2, 1], dtype=int64)

# %%
m.setObjective(quicksum(skills_rating[i][j] * invited[i] for i in range(150) for j in range(7)), GRB.MAXIMIZE)

# %%
m.addConstr(quicksum(invited[i] for i in range(150)) == 21)
# Out:
# <gurobi.Constr *Awaiting Model Update*>

# %%
m.addConstr(quicksum(invited[i] for i in range(150) if players_positions[i] in ['G', 'G/F']) >= 0.3 * 21)
m.addConstr(quicksum(invited[i] for i in range(150) if players_positions[i] in ['F', 'C', 'F/C']) >= 0.4 * 21)
# Out:
# <gurobi.Constr *Awaiting Model Update*>

# %%
for j in range(7):
    m.addConstr((1 / 21) * quicksum(skills_rating[i][j] * invited[i] for i in range(150)) >= 2.05)

# %%
m.addConstr(gb.quicksum(invited[i] for i in range(19, 24)) <= 5 + 5 * gb.quicksum(1 - invited[j] for j in range(71, 78)))

for i in range(104, 114):
    for k in range(44, 49):
        for l in range(64, 69):
            m.addConstr(2*invited[i] <= invited[k]+invited[l])

# %%
for j in range(15):
    m.addConstr(quicksum(invited[i] for i in range(j*10 , (j+1)*10)) >= 1)

# %%
for j in range(15):
  lower_bound = j * 10 
  upper_bound = (j + 1) * 10
  print(f"Range for invited[{j}]: ({lower_bound}, {upper_bound})")
# Out:
# Range for invited[0]: (0, 10)
# Range for invited[1]: (10, 20)
# Range for invited[2]: (20, 30)
# Range for invited[3]: (30, 40)
# Range for invited[4]: (40, 50)
# Range for invited[5]: (50, 60)
# Range for invited[6]: (60, 70)
# Range for invited[7]: (70, 80)
# Range for invited[8]: (80, 90)
# Range for invited[9]: (90, 100)
# Range for invited[10]: (100, 110)
# Range for invited[11]: (110, 120)
# Range for invited[12]: (120, 130)
# Range for invited[13]: (130, 140)
# Range for invited[14]: (140, 150)

# %%
m.optimize()
# Out:
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11.0 (22621.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 276 rows, 150 columns and 2262 nonzeros
# Model fingerprint: 0xef44a8b7
# Variable types: 0 continuous, 150 integer (150 binary)
# Coefficient statistics:
#   Matrix range     [5e-02, 5e+00]
#   Objective range  [9e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+01]
# Presolve removed 1 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 275 rows, 150 columns, 1911 nonzeros
# Variable types: 0 continuous, 150 integer (150 binary)
#
# Root relaxation: objective 3.580000e+02, 12 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     358.0000000  358.00000  0.00%     -    0s
#
# Explored 1 nodes (12 simplex iterations) in 0.01 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 358
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.580000000000e+02, best bound 3.580000000000e+02, gap 0.0000%

# %%
selected_players = []
print("Selected players:")
for i in range(150):
    if invited[i].X > 0.5:
        selected_players.append(i)
        print(f"Player {i+1}")
        
print("\nTotal skill level of selected players:", m.objVal)
# Out:
# Selected players:
# Player 5
# Player 7
# Player 11
# Player 26
# Player 37
# Player 41
# Player 56
# Player 70
# Player 74
# Player 76
# Player 90
# Player 95
# Player 104
# Player 118
# Player 128
# Player 132
# Player 133
# Player 134
# Player 141
# Player 144
# Player 148
#
# Total skill level of selected players: 358.0

# %% [markdown]
# # g

# %%
num_guards = sum(1 for i in selected_players if 'G' in players_positions[i])
print("Number of guards invited:", num_guards)
# Out:
# Number of guards invited: 9

# %% [markdown]
# # h

# %%
m_f = gb.Model("Player_Selection")
x = m_f.addVars(150, vtype=GRB.BINARY, name="x")
m_f.setObjective(quicksum(skills_rating[i][j] * x[i] for i in range(150) for j in range(7)), GRB.MAXIMIZE)
    
m_f.addConstr(quicksum(x[i] for i in range(150) if players_positions[i] in ['G', 'G/F']) >= 0.3 * 21)
m_f.addConstr(quicksum(x[i] for i in range(150) if players_positions[i] in ['F', 'C', 'F/C']) >= 0.4 * 21)
    
for j in range(7):
    m_f.addConstr((1 / 21) * quicksum(skills_rating[i][j] * x[i] for i in range(150)) >= 2.05)
    
m_f.addConstr(gb.quicksum(x[i] for i in range(19, 24)) <= 5 + 5 * gb.quicksum(1 - x[j] for j in range(71, 78)))

for i in range(104, 114):
  for k in range(44, 49):
    for l in range(64, 69):
        m_f.addConstr(2*x[i] <= x[k]+x[l])
    
for j in range(15):
    m_f.addConstr(quicksum(x[i] for i in range(j*10 , (j+1)*10)) >= 1)
    
# Solve the model iteratively
num_invitations = 150
while True:
    # Set the maximum number of solutions to 2
    m_f.setParam('PoolSolutions', 2)
    
    # Set the maximum time limit for optimization
    m_f.setParam('TimeLimit', 600)  # 10 minutes
    
    # Optimize the model
    m_f.optimize()
    
    # If the model is infeasible, print the smallest number of invitations and break the loop
    if m_f.status == gb.GRB.INFEASIBLE:
        print("Smallest number of invitations:", num_invitations)
        break
    
    # Decrease the number of invitations by 1 for the next iteration
    num_invitations -= 1
    
    # Update the constraint for the new number of invitations
    m_f.addConstr(gb.quicksum(x[i] for i in range(150)) <= num_invitations)
# Out:
# Set parameter PoolSolutions to value 2
# Set parameter TimeLimit to value 600
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11.0 (22621.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 275 rows, 150 columns and 2112 nonzeros
# Model fingerprint: 0x577e7c95
# Variable types: 0 continuous, 150 integer (150 binary)
# Coefficient statistics:
#   Matrix range     [5e-02, 5e+00]
#   Objective range  [9e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+01]
# Found heuristic solution: objective 2133.0000000
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 2133
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.133000000000e+03, best bound 2.133000000000e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11.0 (22621.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 276 rows, 150 columns and 2262 nonzeros
# Model fingerprint: 0x4fc3bce0
# Variable types: 0 continuous, 150 integer (150 binary)
# Coefficient statistics:
#   Matrix range     [5e-02, 5e+00]
#   Objective range  [9e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R275 by 1.000000000
#
# Found heuristic solution: objective 2118.0000000
# Presolve removed 276 rows and 150 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 2: 2124 2118
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.124000000000e+03, best bound 2.124000000000e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11.0 (22621.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 277 rows, 150 columns and 2412 nonzeros
# Model fingerprint: 0x6a44538f
# Variable types: 0 continuous, 150 integer (150 binary)
# Coefficient statistics:
#   Matrix range     [5e-02, 5e+00]
#   Objective range  [9e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R276 by 1.000000000
#
# Found heuristic solution: objective 2106.0000000
# Presolve removed 254 rows and 10 columns
# Presolve time: 0.00s
# Presolved: 23 rows, 140 columns, 1390 nonzeros
# Variable types: 0 continuous, 140 integer (140 binary)
# Found heuristic solution: objective 2110.0000000
#
# Root relaxation: objective 2.114000e+03, 1 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2114.0000000 2114.00000  0.00%     -    0s
#
# Explored 1 nodes (1 simplex iterations) in 0.02 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 2114 2110
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.114000000000e+03, best bound 2.114000000000e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11.0 (22621.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 278 rows, 150 columns and 2562 nonzeros
# Model fingerprint: 0x3d4c825b
# Variable types: 0 continuous, 150 integer (150 binary)
# Coefficient statistics:
#   Matrix range     [5e-02, 5e+00]
#   Objective range  [9e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R277 by 1.000000000
#
# Found heuristic solution: objective 2090.0000000
# Presolve removed 255 rows and 10 columns
# Presolve time: 0.00s
# Presolved: 23 rows, 140 columns, 1390 nonzeros
# Variable types: 0 continuous, 140 integer (140 binary)
# Found heuristic solution: objective 2097.0000000
#
# Root relaxation: objective 2.104000e+03, 1 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2104.0000000 2104.00000  0.00%     -    0s
#
# Explored 1 nodes (1 simplex iterations) in 0.02 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 2104 2097
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.104000000000e+03, best bound 2.104000000000e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11.0 (22621.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 279 rows, 150 columns and 2712 nonzeros
# Model fingerprint: 0x6e26533d
# Variable types: 0 continuous, 150 integer (150 binary)
# Coefficient statistics:
#   Matrix range     [5e-02, 5e+00]
#   Objective range  [9e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R278 by 1.000000000
#
# Found heuristic solution: objective 2075.0000000
# Presolve removed 256 rows and 10 columns
# Presolve time: 0.01s
# Presolved: 23 rows, 140 columns, 1390 nonzeros
# Variable types: 0 continuous, 140 integer (140 binary)
# Found heuristic solution: objective 2084.0000000
#
# Root relaxation: objective 2.093000e+03, 1 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2093.0000000 2093.00000  0.00%     -    0s
#
# Explored 1 nodes (1 simplex iterations) in 0.03 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 2093 2084
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.093000000000e+03, best bound 2.093000000000e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11.0 (22621.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 280 rows, 150 columns and 2862 nonzeros
# Model fingerprint: 0xfecc937e
# Variable types: 0 continuous, 150 integer (150 binary)
# Coefficient statistics:
#   Matrix range     [5e-02, 5e+00]
#   Objective range  [9e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R279 by 1.000000000
#
# Found heuristic solution: objective 2061.0000000
# Presolve removed 257 rows and 10 columns
# Presolve time: 0.00s
# Presolved: 23 rows, 140 columns, 1390 nonzeros
# Variable types: 0 continuous, 140 integer (140 binary)
# Found heuristic solution: objective 2071.0000000
#
# Root relaxation: objective 2.082000e+03, 1 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2082.0000000 2082.00000  0.00%     -    0s
#
# Explored 1 nodes (1 simplex iterations) in 0.11 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 2082 2071
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.082000000000e+03, best bound 2.082000000000e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11.0 (22621.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 281 rows, 150 columns and 3012 nonzeros
# Model fingerprint: 0x3d1973bb
# Variable types: 0 continuous, 150 integer (150 binary)
# Coefficient statistics:
#   Matrix range     [5e-02, 5e+00]
#   Objective range  [9e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R280 by 1.000000000
#
# Found heuristic solution: objective 2044.0000000
# Presolve removed 258 rows and 10 columns
# Presolve time: 0.00s
# Presolved: 23 rows, 140 columns, 1390 nonzeros
# Variable types: 0 continuous, 140 integer (140 binary)
# Found heuristic solution: objective 2059.0000000
#
# Root relaxation: objective 2.071000e+03, 1 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2071.0000000 2071.00000  0.00%     -    0s
#
# Explored 1 nodes (1 simplex iterations) in 0.02 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 2071 2059
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.071000000000e+03, best bound 2.071000000000e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11.0 (22621.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 282 rows, 150 columns and 3162 nonzeros
# Model fingerprint: 0xbd7956c5
# Variable types: 0 continuous, 150 integer (150 binary)
# Coefficient statistics:
#   Matrix range     [5e-02, 5e+00]
#   Objective range  [9e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R281 by 1.000000000
#
# Found heuristic solution: objective 2030.0000000
# Presolve removed 259 rows and 10 columns
# Presolve time: 0.00s
# Presolved: 23 rows, 140 columns, 1390 nonzeros
# Variable types: 0 continuous, 140 integer (140 binary)
# Found heuristic solution: objective 2045.0000000
#
# Root relaxation: objective 2.060000e+03, 1 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2060.0000000 2060.00000  0.00%     -    0s
#
# Explored 1 nodes (1 simplex iterations) in 0.02 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 2060 2045
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.060000000000e+03, best bound 2.060000000000e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11.0 (22621.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 283 rows, 150 columns and 3312 nonzeros
# Model fingerprint: 0xca026dd7
# Variable types: 0 continuous, 150 integer (150 binary)
# Coefficient statistics:
#   Matrix range     [5e-02, 5e+00]
#   Objective range  [9e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R282 by 1.000000000
#
# Found heuristic solution: objective 2013.0000000
# Presolve removed 260 rows and 10 columns
# Presolve time: 0.00s
# Presolved: 23 rows, 140 columns, 1390 nonzeros
# Variable types: 0 continuous, 140 integer (140 binary)
# Found heuristic solution: objective 2031.0000000
#
# Root relaxation: objective 2.049000e+03, 1 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2049.0000000 2049.00000  0.00%     -    0s
#
# Explored 1 nodes (1 simplex iterations) in 0.02 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 2049 2031
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.049000000000e+03, best bound 2.049000000000e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11.0 (22621.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 284 rows, 150 columns and 3462 nonzeros
# Model fingerprint: 0xd835497b
# Variable types: 0 continuous, 150 integer (150 binary)
# Coefficient statistics:
#   Matrix range     [5e-02, 5e+00]
#   Objective range  [9e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R283 by 1.000000000
#
# Found heuristic solution: objective 2002.0000000
# Presolve removed 261 rows and 10 columns
# Presolve time: 0.01s
# Presolved: 23 rows, 140 columns, 1390 nonzeros
# Variable types: 0 continuous, 140 integer (140 binary)
# Found heuristic solution: objective 2022.0000000
#
# Root relaxation: objective 2.038000e+03, 1 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2038.0000000 2038.00000  0.00%     -    0s
#
# Explored 1 nodes (1 simplex iterations) in 0.02 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 2038 2022
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.038000000000e+03, best bound 2.038000000000e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11.0 (22621.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 285 rows, 150 columns and 3612 nonzeros
# Model fingerprint: 0xc03082bc
# Variable types: 0 continuous, 150 integer (150 binary)
# Coefficient statistics:
#   Matrix range     [5e-02, 5e+00]
#   Objective range  [9e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R284 by 1.000000000
#
# Found heuristic solution: objective 1986.0000000
# Presolve removed 262 rows and 10 columns
# Presolve time: 0.00s
# Presolved: 23 rows, 140 columns, 1390 nonzeros
# Variable types: 0 continuous, 140 integer (140 binary)
# Found heuristic solution: objective 2007.0000000
#
# Root relaxation: objective 2.027000e+03, 1 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2027.0000000 2027.00000  0.00%     -    0s
#
# Explored 1 nodes (1 simplex iterations) in 0.07 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 2027 2007
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.027000000000e+03, best bound 2.027000000000e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11.0 (22621.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 286 rows, 150 columns and 3762 nonzeros
# Model fingerprint: 0x0f660f31
# Variable types: 0 continuous, 150 integer (150 binary)
# Coefficient statistics:
#   Matrix range     [5e-02, 5e+00]
#   Objective range  [9e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R285 by 1.000000000
#
# Found heuristic solution: objective 1970.0000000
# Presolve removed 172 rows and 1 columns
# Presolve time: 0.01s
# Presolved: 114 rows, 149 columns, 1661 nonzeros
# Variable types: 0 continuous, 149 integer (149 binary)
# Found heuristic solution: objective 1991.0000000
#
# Root relaxation: objective 2.016000e+03, 1 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2016.0000000 2016.00000  0.00%     -    0s
#
# Explored 1 nodes (1 simplex iterations) in 0.02 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 2016 1991
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.016000000000e+03, best bound 2.016000000000e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11.0 (22621.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 287 rows, 150 columns and 3912 nonzeros
# Model fingerprint: 0xf55994d6
# Variable types: 0 continuous, 150 integer (150 binary)
# Coefficient statistics:
#   Matrix range     [5e-02, 5e+00]
#   Objective range  [9e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R286 by 1.000000000
#
# Found heuristic solution: objective 1956.0000000
# Presolve removed 12 rows and 0 columns
# Presolve time: 0.01s
# Presolved: 275 rows, 150 columns, 2250 nonzeros
# Variable types: 0 continuous, 150 integer (150 binary)
# Found heuristic solution: objective 1978.0000000
#
# Root relaxation: objective 2.004000e+03, 1 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2004.0000000 2004.00000  0.00%     -    0s
#
# Explored 1 nodes (1 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 2004 1978
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.004000000000e+03, best bound 2.004000000000e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11.0 (22621.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 288 rows, 150 columns and 4062 nonzeros
# Model fingerprint: 0x5d1cd9ed
# Variable types: 0 continuous, 150 integer (150 binary)
# Coefficient statistics:
#   Matrix range     [5e-02, 5e+00]
#   Objective range  [9e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R287 by 1.000000000
#
# Found heuristic solution: objective 1942.0000000
# Presolve removed 13 rows and 0 columns
# Presolve time: 0.01s
# Presolved: 275 rows, 150 columns, 2250 nonzeros
# Variable types: 0 continuous, 150 integer (150 binary)
# Found heuristic solution: objective 1965.0000000
#
# Root relaxation: objective 1.992000e+03, 4 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1992.0000000 1992.00000  0.00%     -    0s
#
# Explored 1 nodes (4 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 1992 1965
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.992000000000e+03, best bound 1.992000000000e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11.0 (22621.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 289 rows, 150 columns and 4212 nonzeros
# Model fingerprint: 0x893f016f
# Variable types: 0 continuous, 150 integer (150 binary)
# Coefficient statistics:
#   Matrix range     [5e-02, 5e+00]
#   Objective range  [9e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R288 by 1.000000000
#
# Found heuristic solution: objective 1925.0000000
# Presolve removed 14 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 275 rows, 150 columns, 2250 nonzeros
# Variable types: 0 continuous, 150 integer (150 binary)
# Found heuristic solution: objective 1951.0000000
#
# Root relaxation: objective 1.980000e+03, 4 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1980.0000000 1980.00000  0.00%     -    0s
#
# Explored 1 nodes (4 simplex iterations) in 0.03 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 1980 1951
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.980000000000e+03, best bound 1.980000000000e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11.0 (22621.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 290 rows, 150 columns and 4362 nonzeros
# Model fingerprint: 0xebd44d77
# Variable types: 0 continuous, 150 integer (150 binary)
# Coefficient statistics:
#   Matrix range     [5e-02, 5e+00]
#   Objective range  [9e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R289 by 1.000000000
#
# Found heuristic solution: objective 1907.0000000
# Presolve removed 15 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 275 rows, 150 columns, 2250 nonzeros
# Variable types: 0 continuous, 150 integer (150 binary)
# Found heuristic solution: objective 1936.0000000
#
# Root relaxation: objective 1.968000e+03, 4 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1968.0000000 1968.00000  0.00%     -    0s
#
# Explored 1 nodes (4 simplex iterations) in 0.02 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 1968 1936
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.968000000000e+03, best bound 1.968000000000e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11.0 (22621.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 291 rows, 150 columns and 4512 nonzeros
# Model fingerprint: 0xe9ba61ec
# Variable types: 0 continuous, 150 integer (150 binary)
# Coefficient statistics:
#   Matrix range     [5e-02, 5e+00]
#   Objective range  [9e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R290 by 1.000000000
#
# Found heuristic solution: objective 1890.0000000
# Presolve removed 16 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 275 rows, 150 columns, 2250 nonzeros
# Variable types: 0 continuous, 150 integer (150 binary)
# Found heuristic solution: objective 1920.0000000
#
# Root relaxation: objective 1.956000e+03, 5 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1956.0000000 1956.00000  0.00%     -    0s
#
# Explored 1 nodes (5 simplex iterations) in 0.02 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 1956 1920
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.956000000000e+03, best bound 1.956000000000e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11.0 (22621.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 292 rows, 150 columns and 4662 nonzeros
# Model fingerprint: 0x8a2a1eb9
# Variable types: 0 continuous, 150 integer (150 binary)
# Coefficient statistics:
#   Matrix range     [5e-02, 5e+00]
#   Objective range  [9e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R291 by 1.000000000
#
# Found heuristic solution: objective 1874.0000000
# Presolve removed 17 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 275 rows, 150 columns, 2250 nonzeros
# Variable types: 0 continuous, 150 integer (150 binary)
# Found heuristic solution: objective 1909.0000000
#
# Root relaxation: objective 1.944000e+03, 5 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1944.0000000 1944.00000  0.00%     -    0s
#
# Explored 1 nodes (5 simplex iterations) in 0.12 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 1944 1909
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.944000000000e+03, best bound 1.944000000000e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11.0 (22621.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 293 rows, 150 columns and 4812 nonzeros
# Model fingerprint: 0x5b36cacc
# Variable types: 0 continuous, 150 integer (150 binary)
# Coefficient statistics:
#   Matrix range     [5e-02, 5e+00]
#   Objective range  [9e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R292 by 1.000000000
#
# Found heuristic solution: objective 1860.0000000
# Presolve removed 18 rows and 0 columns
# Presolve time: 0.01s
# Presolved: 275 rows, 150 columns, 2250 nonzeros
# Variable types: 0 continuous, 150 integer (150 binary)
# Found heuristic solution: objective 1894.0000000
#
# Root relaxation: objective 1.932000e+03, 5 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1932.0000000 1932.00000  0.00%     -    0s
#
# Explored 1 nodes (5 simplex iterations) in 0.02 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 1932 1894
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.932000000000e+03, best bound 1.932000000000e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11.0 (22621.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 294 rows, 150 columns and 4962 nonzeros
# Model fingerprint: 0x6e09cc22
# Variable types: 0 continuous, 150 integer (150 binary)
# Coefficient statistics:
#   Matrix range     [5e-02, 5e+00]
#   Objective range  [9e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R293 by 1.000000000
#
# Found heuristic solution: objective 1847.0000000
# Presolve removed 19 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 275 rows, 150 columns, 2250 nonzeros
# Variable types: 0 continuous, 150 integer (150 binary)
# Found heuristic solution: objective 1877.0000000
#
# Root relaxation: objective 1.920000e+03, 5 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1920.0000000 1920.00000  0.00%     -    0s
#
# Explored 1 nodes (5 simplex iterations) in 0.02 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 1920 1877
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.920000000000e+03, best bound 1.920000000000e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11.0 (22621.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 295 rows, 150 columns and 5112 nonzeros
# Model fingerprint: 0x30c5d90a
# Variable types: 0 continuous, 150 integer (150 binary)
# Coefficient statistics:
#   Matrix range     [5e-02, 5e+00]
#   Objective range  [9e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R294 by 1.000000000
#
# Found heuristic solution: objective 1831.0000000
# Presolve removed 20 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 275 rows, 150 columns, 2250 nonzeros
# Variable types: 0 continuous, 150 integer (150 binary)
# Found heuristic solution: objective 1864.0000000
#
# Root relaxation: objective 1.908000e+03, 5 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1908.0000000 1908.00000  0.00%     -    0s
#
# Explored 1 nodes (5 simplex iterations) in 0.02 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 1908 1864
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.908000000000e+03, best bound 1.908000000000e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11.0 (22621.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 296 rows, 150 columns and 5262 nonzeros
# Model fingerprint: 0x86a2e944
# Variable types: 0 continuous, 150 integer (150 binary)
# Coefficient statistics:
#   Matrix range     [5e-02, 5e+00]
#   Objective range  [9e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R295 by 1.000000000
#
# Found heuristic solution: objective 1818.0000000
# Presolve removed 21 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 275 rows, 150 columns, 2250 nonzeros
# Variable types: 0 continuous, 150 integer (150 binary)
# Found heuristic solution: objective 1850.0000000
#
# Root relaxation: objective 1.896000e+03, 5 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1896.0000000 1896.00000  0.00%     -    0s
#
# Explored 1 nodes (5 simplex iterations) in 0.02 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 1896 1850
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.896000000000e+03, best bound 1.896000000000e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11.0 (22621.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 297 rows, 150 columns and 5412 nonzeros
# Model fingerprint: 0xbec0c532
# Variable types: 0 continuous, 150 integer (150 binary)
# Coefficient statistics:
#   Matrix range     [5e-02, 5e+00]
#   Objective range  [9e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R296 by 1.000000000
#
# Found heuristic solution: objective 1806.0000000
# Presolve removed 22 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 275 rows, 150 columns, 2250 nonzeros
# Variable types: 0 continuous, 150 integer (150 binary)
# Found heuristic solution: objective 1840.0000000
#
# Root relaxation: objective 1.884000e+03, 5 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1884.0000000 1884.00000  0.00%     -    0s
#
# Explored 1 nodes (5 simplex iterations) in 0.02 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 1884 1840
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.884000000000e+03, best bound 1.884000000000e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11.0 (22621.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 298 rows, 150 columns and 5562 nonzeros
# Model fingerprint: 0x644e4e5a
# Variable types: 0 continuous, 150 integer (150 binary)
# Coefficient statistics:
#   Matrix range     [5e-02, 5e+00]
#   Objective range  [9e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R297 by 1.000000000
#
# Found heuristic solution: objective 1792.0000000
# Presolve removed 23 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 275 rows, 150 columns, 2250 nonzeros
# Variable types: 0 continuous, 150 integer (150 binary)
# Found heuristic solution: objective 1827.0000000
#
# Root relaxation: objective 1.872000e+03, 5 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1872.0000000 1872.00000  0.00%     -    0s
#
# Explored 1 nodes (5 simplex iterations) in 0.02 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 1872 1827
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.872000000000e+03, best bound 1.872000000000e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11.0 (22621.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 299 rows, 150 columns and 5712 nonzeros
# Model fingerprint: 0x3eb5b3e8
# Variable types: 0 continuous, 150 integer (150 binary)
# Coefficient statistics:
#   Matrix range     [5e-02, 5e+00]
#   Objective range  [9e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R298 by 1.000000000
#
# Found heuristic solution: objective 1780.0000000
# Presolve removed 24 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 275 rows, 150 columns, 2250 nonzeros
# Variable types: 0 continuous, 150 integer (150 binary)
# Found heuristic solution: objective 1817.0000000
#
# Root relaxation: objective 1.860000e+03, 5 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1860.0000000 1860.00000  0.00%     -    0s
#
# Explored 1 nodes (5 simplex iterations) in 0.02 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 1860 1817
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.860000000000e+03, best bound 1.860000000000e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11.0 (22621.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 300 rows, 150 columns and 5862 nonzeros
# Model fingerprint: 0xac7dc9f6
# Variable types: 0 continuous, 150 integer (150 binary)
# Coefficient statistics:
#   Matrix range     [5e-02, 5e+00]
#   Objective range  [9e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R299 by 1.000000000
#
# Found heuristic solution: objective 1766.0000000
# Presolve removed 25 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 275 rows, 150 columns, 2250 nonzeros
# Variable types: 0 continuous, 150 integer (150 binary)
# Found heuristic solution: objective 1802.0000000
#
# Root relaxation: objective 1.848000e+03, 5 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1848.0000000 1848.00000  0.00%     -    0s
#
# Explored 1 nodes (5 simplex iterations) in 0.02 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 1848 1802
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.848000000000e+03, best bound 1.848000000000e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11.0 (22621.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 301 rows, 150 columns and 6012 nonzeros
# Model fingerprint: 0xf16a62f1
# Variable types: 0 continuous, 150 integer (150 binary)
# Coefficient statistics:
#   Matrix range     [5e-02, 5e+00]
#   Objective range  [9e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R300 by 1.000000000
#
# Found heuristic solution: objective 1753.0000000
# Presolve removed 26 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 275 rows, 150 columns, 2250 nonzeros
# Variable types: 0 continuous, 150 integer (150 binary)
# Found heuristic solution: objective 1791.0000000
#
# Root relaxation: objective 1.836000e+03, 5 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1836.0000000 1836.00000  0.00%     -    0s
#
# Explored 1 nodes (5 simplex iterations) in 0.03 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 1836 1791
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.836000000000e+03, best bound 1.836000000000e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11.0 (22621.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 302 rows, 150 columns and 6162 nonzeros
# Model fingerprint: 0x09c3afaa
# Variable types: 0 continuous, 150 integer (150 binary)
# Coefficient statistics:
#   Matrix range     [5e-02, 5e+00]
#   Objective range  [9e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R301 by 1.000000000
#
# Found heuristic solution: objective 1736.0000000
# Presolve removed 27 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 275 rows, 150 columns, 2250 nonzeros
# Variable types: 0 continuous, 150 integer (150 binary)
# Found heuristic solution: objective 1779.0000000
#
# Root relaxation: objective 1.824000e+03, 5 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1824.0000000 1824.00000  0.00%     -    0s
#
# Explored 1 nodes (5 simplex iterations) in 0.02 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 1824 1779
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.824000000000e+03, best bound 1.824000000000e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11.0 (22621.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 303 rows, 150 columns and 6312 nonzeros
# Model fingerprint: 0x8fe5319d
# Variable types: 0 continuous, 150 integer (150 binary)
# Coefficient statistics:
#   Matrix range     [5e-02, 5e+00]
#   Objective range  [9e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R302 by 1.000000000
#
# Found heuristic solution: objective 1723.0000000
# Presolve removed 28 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 275 rows, 150 columns, 2250 nonzeros
# Variable types: 0 continuous, 150 integer (150 binary)
# Found heuristic solution: objective 1763.0000000
#
# Root relaxation: objective 1.811000e+03, 10 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1811.0000000 1811.00000  0.00%     -    0s
#
# Explored 1 nodes (10 simplex iterations) in 0.02 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 1811 1763
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.811000000000e+03, best bound 1.811000000000e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11.0 (22621.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 304 rows, 150 columns and 6462 nonzeros
# Model fingerprint: 0xad1d0cac
# Variable types: 0 continuous, 150 integer (150 binary)
# Coefficient statistics:
#   Matrix range     [5e-02, 5e+00]
#   Objective range  [9e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R303 by 1.000000000
#
# Found heuristic solution: objective 1711.0000000
# Presolve removed 29 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 275 rows, 150 columns, 2250 nonzeros
# Variable types: 0 continuous, 150 integer (150 binary)
# Found heuristic solution: objective 1752.0000000
#
# Root relaxation: objective 1.798000e+03, 12 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1798.0000000 1798.00000  0.00%     -    0s
#
# Explored 1 nodes (12 simplex iterations) in 0.02 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 1798 1752
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.798000000000e+03, best bound 1.798000000000e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11.0 (22621.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 305 rows, 150 columns and 6612 nonzeros
# Model fingerprint: 0x29547489
# Variable types: 0 continuous, 150 integer (150 binary)
# Coefficient statistics:
#   Matrix range     [5e-02, 5e+00]
#   Objective range  [9e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R304 by 1.000000000
#
# Found heuristic solution: objective 1700.0000000
# Presolve removed 30 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 275 rows, 150 columns, 2250 nonzeros
# Variable types: 0 continuous, 150 integer (150 binary)
# Found heuristic solution: objective 1740.0000000
#
# Root relaxation: objective 1.785000e+03, 9 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1785.0000000 1785.00000  0.00%     -    0s
#
# Explored 1 nodes (9 simplex iterations) in 0.02 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 1785 1740
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.785000000000e+03, best bound 1.785000000000e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11.0 (22621.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 306 rows, 150 columns and 6762 nonzeros
# Model fingerprint: 0xa2f1dcb9
# Variable types: 0 continuous, 150 integer (150 binary)
# Coefficient statistics:
#   Matrix range     [5e-02, 5e+00]
#   Objective range  [9e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R305 by 1.000000000
#
# ...
#
# Found heuristic solution: objective 390.0000000
# Presolve removed 122 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 275 rows, 150 columns, 2250 nonzeros
# Variable types: 0 continuous, 150 integer (150 binary)
# Found heuristic solution: objective 467.0000000
#
# Root relaxation: objective 4.710000e+02, 10 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     471.0000000  471.00000  0.00%     -    0s
#
# Explored 1 nodes (10 simplex iterations) in 0.03 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 471 467
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.710000000000e+02, best bound 4.710000000000e+02, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11.0 (22621.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 398 rows, 150 columns and 20562 nonzeros
# Model fingerprint: 0x6b721315
# Variable types: 0 continuous, 150 integer (150 binary)
# Coefficient statistics:
#   Matrix range     [5e-02, 5e+00]
#   Objective range  [9e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R397 by 1.000000000
#
# Found heuristic solution: objective 380.0000000
# Presolve removed 123 rows and 0 columns
# Presolve time: 0.01s
# Presolved: 275 rows, 150 columns, 2250 nonzeros
# Variable types: 0 continuous, 150 integer (150 binary)
# Found heuristic solution: objective 451.0000000
#
# Root relaxation: objective 4.550000e+02, 10 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     455.0000000  455.00000  0.00%     -    0s
#
# Explored 1 nodes (10 simplex iterations) in 0.12 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 455 451
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.550000000000e+02, best bound 4.550000000000e+02, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11.0 (22621.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 399 rows, 150 columns and 20712 nonzeros
# Model fingerprint: 0x2ff68c9f
# Variable types: 0 continuous, 150 integer (150 binary)
# Coefficient statistics:
#   Matrix range     [5e-02, 5e+00]
#   Objective range  [9e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R398 by 1.000000000
#
# Found heuristic solution: objective 369.0000000
# Presolve removed 124 rows and 0 columns
# Presolve time: 0.01s
# Presolved: 275 rows, 150 columns, 2250 nonzeros
# Variable types: 0 continuous, 150 integer (150 binary)
# Found heuristic solution: objective 436.0000000
#
# Root relaxation: objective 4.390000e+02, 11 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     439.0000000  439.00000  0.00%     -    0s
#
# Explored 1 nodes (11 simplex iterations) in 0.03 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 439 436
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.390000000000e+02, best bound 4.390000000000e+02, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11.0 (22621.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 400 rows, 150 columns and 20862 nonzeros
# Model fingerprint: 0x3e3846b6
# Variable types: 0 continuous, 150 integer (150 binary)
# Coefficient statistics:
#   Matrix range     [5e-02, 5e+00]
#   Objective range  [9e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R399 by 1.000000000
#
# Found heuristic solution: objective 352.0000000
# Presolve removed 125 rows and 0 columns
# Presolve time: 0.01s
# Presolved: 275 rows, 150 columns, 2250 nonzeros
# Variable types: 0 continuous, 150 integer (150 binary)
# Found heuristic solution: objective 421.0000000
#
# Root relaxation: objective 4.230000e+02, 10 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     423.0000000  423.00000  0.00%     -    0s
#
# Explored 1 nodes (10 simplex iterations) in 0.03 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 423 421
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.230000000000e+02, best bound 4.230000000000e+02, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11.0 (22621.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 401 rows, 150 columns and 21012 nonzeros
# Model fingerprint: 0x5b7f6c16
# Variable types: 0 continuous, 150 integer (150 binary)
# Coefficient statistics:
#   Matrix range     [5e-02, 5e+00]
#   Objective range  [9e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R400 by 1.000000000
#
# Found heuristic solution: objective 333.0000000
# Presolve removed 126 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 275 rows, 150 columns, 2250 nonzeros
# Variable types: 0 continuous, 150 integer (150 binary)
# Found heuristic solution: objective 405.0000000
#
# Root relaxation: objective 4.070000e+02, 10 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     407.0000000  407.00000  0.00%     -    0s
#
# Explored 1 nodes (10 simplex iterations) in 0.02 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 407 405
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.070000000000e+02, best bound 4.070000000000e+02, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11.0 (22621.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 402 rows, 150 columns and 21162 nonzeros
# Model fingerprint: 0x07485cb6
# Variable types: 0 continuous, 150 integer (150 binary)
# Coefficient statistics:
#   Matrix range     [5e-02, 5e+00]
#   Objective range  [9e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R401 by 1.000000000
#
# Found heuristic solution: objective 343.0000000
# Presolve removed 127 rows and 0 columns
# Presolve time: 0.01s
# Presolved: 275 rows, 150 columns, 2250 nonzeros
# Variable types: 0 continuous, 150 integer (150 binary)
# Found heuristic solution: objective 389.0000000
#
# Root relaxation: objective 3.910000e+02, 12 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     391.0000000  391.00000  0.00%     -    0s
#
# Explored 1 nodes (12 simplex iterations) in 0.02 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 391 389
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.910000000000e+02, best bound 3.910000000000e+02, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11.0 (22621.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 403 rows, 150 columns and 21312 nonzeros
# Model fingerprint: 0x06e4ec9f
# Variable types: 0 continuous, 150 integer (150 binary)
# Coefficient statistics:
#   Matrix range     [5e-02, 5e+00]
#   Objective range  [9e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R402 by 1.000000000
#
# Presolve removed 128 rows and 0 columns
# Presolve time: 0.01s
# Presolved: 275 rows, 150 columns, 2250 nonzeros
# Variable types: 0 continuous, 150 integer (150 binary)
#
# Root relaxation: objective 3.750000e+02, 13 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     375.0000000  375.00000  0.00%     -    0s
#
# Explored 1 nodes (13 simplex iterations) in 0.02 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 375
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.750000000000e+02, best bound 3.750000000000e+02, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11.0 (22621.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 404 rows, 150 columns and 21462 nonzeros
# Model fingerprint: 0x556ddc62
# Variable types: 0 continuous, 150 integer (150 binary)
# Coefficient statistics:
#   Matrix range     [5e-02, 5e+00]
#   Objective range  [9e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R403 by 1.000000000
#
# Presolve removed 129 rows and 0 columns
# Presolve time: 0.01s
# Presolved: 275 rows, 150 columns, 2250 nonzeros
# Variable types: 0 continuous, 150 integer (150 binary)
#
# Root relaxation: objective 3.580000e+02, 11 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     358.0000000  358.00000  0.00%     -    0s
#
# Explored 1 nodes (11 simplex iterations) in 0.10 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 358
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.580000000000e+02, best bound 3.580000000000e+02, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11.0 (22621.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 405 rows, 150 columns and 21612 nonzeros
# Model fingerprint: 0xd499f83c
# Variable types: 0 continuous, 150 integer (150 binary)
# Coefficient statistics:
#   Matrix range     [5e-02, 5e+00]
#   Objective range  [9e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R404 by 1.000000000
#
# Presolve removed 130 rows and 0 columns
# Presolve time: 0.01s
# Presolved: 275 rows, 150 columns, 2250 nonzeros
# Variable types: 0 continuous, 150 integer (150 binary)
#
# Root relaxation: objective 3.410000e+02, 13 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  341.00000    0    2          -  341.00000      -     -    0s
# H    0     0                     341.0000000  341.00000  0.00%     -    0s
#
# Explored 1 nodes (13 simplex iterations) in 0.03 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 341
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.410000000000e+02, best bound 3.410000000000e+02, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11.0 (22621.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 406 rows, 150 columns and 21762 nonzeros
# Model fingerprint: 0xedea5af8
# Variable types: 0 continuous, 150 integer (150 binary)
# Coefficient statistics:
#   Matrix range     [5e-02, 5e+00]
#   Objective range  [9e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R405 by 1.000000000
#
# Presolve removed 131 rows and 0 columns
# Presolve time: 0.01s
# Presolved: 275 rows, 150 columns, 2250 nonzeros
# Variable types: 0 continuous, 150 integer (150 binary)
#
# Root relaxation: objective 3.240000e+02, 20 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     324.0000000  324.00000  0.00%     -    0s
#
# Explored 1 nodes (20 simplex iterations) in 0.03 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 324
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.240000000000e+02, best bound 3.240000000000e+02, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11.0 (22621.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 407 rows, 150 columns and 21912 nonzeros
# Model fingerprint: 0xd868d893
# Variable types: 0 continuous, 150 integer (150 binary)
# Coefficient statistics:
#   Matrix range     [5e-02, 5e+00]
#   Objective range  [9e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R406 by 1.000000000
#
# Presolve removed 132 rows and 0 columns
# Presolve time: 0.01s
# Presolved: 275 rows, 150 columns, 2250 nonzeros
# Variable types: 0 continuous, 150 integer (150 binary)
#
# Root relaxation: infeasible, 34 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 infeasible    0               - infeasible      -     -    0s
#
# Explored 1 nodes (34 simplex iterations) in 0.03 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 0
# No other solutions better than -1e+100
#
# Model is infeasible
# Best objective -, best bound -, gap -
# Smallest number of invitations: 18

# %% [markdown]
# ### The constraint "m.addConstr(quicksum(invited[i] for i in range(150)) == 21)" cannot be satisfied

# %% [markdown]
# # i

# %%
for i in range(150):
    m.addConstr(quicksum(skills_rating[i][j] * invited[i] for j in range(7)) >= 12 * invited[i])

# %%
quicksum(skills_rating[i][j] * invited[i] for j in range(7)) >= 12 * invited[i]
# Out:
# <gurobi.TempConstr: Selected Players[149] + 3.0 Selected Players[149] + 2.0 Selected Players[149] + Selected Players[149] + 3.0 Selected Players[149] + 2.0 Selected Players[149] + 3.0 Selected Players[149] >= 12.0 Selected Players[149]>
